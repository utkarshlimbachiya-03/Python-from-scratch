# %% [markdown]
# **Slicing String**

# %%
a='utkarsh'
a[0:]
# Out:
# 'utkarsh'

# %%
a[:]
# Out:
# 'utkarsh'

# %%
a[:3]
# Out:
# 'utk'

# %%
a[0:3]
# Out:
# 'utk'

# %%
a[1:4]
# Out:
# 'tka'

# %% [markdown]
# **List**

# %% [markdown]
# List are a sequences of elements inside the sqaure barket and are seprated by Comma

# %%
list=['a','b','c']
list
# Out:
# ['a', 'b', 'c']

# %%
list.append('d')
list
# Out:
# ['a', 'b', 'c', 'd']

# %%
list[0]
# Out:
# 'a'

# %%
list[1:3]
# Out:
# ['b', 'c']

# %% [markdown]
# **Reassigning List**

# %%
# Reassign
list[0]='New'
list
# Out:
# ['New', 'b', 'c', 'd']

# %% [markdown]
# **Nested List**

# %%
# Nested List
# List INSIDE list

nest=[1,2,[3,4]]
nest
# Out:
# [1, 2, [3, 4]]

# %%
nest[2]
# Out:
# [3, 4]

# %%
nest[2][1]
# Out:
# 4

# %%
nest[2][0]
# Out:
# 3

# %%
nest1=[1,2,3,[4,5,['target']]]

# %%
nest1[3]
# Out:
# [4, 5, ['target']]

# %%
nest1[3][0]
# Out:
# 4

# %%
nest1[3][2]
# Out:
# ['target']

# %%
nest1[3][2][0]
# Out:
# 'target'
